# %% [markdown]
# # 10 회귀 분석으로 연속적 타깃 변수 예측

# %% [markdown]
# ## 10.1 선형 회귀

# %% [markdown]
# ### 10.1.1 단순 선형 회귀

# %% [markdown]
# ## 10.2 주택 데이터셋 탐색

# %% [markdown]
# ### 10.2.1 데이터프레임으로 주택 데이터셋 읽기

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### 10.2.2 데이터셋의 중요 특징 시각화

# %%
# !pip install --upgrade mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (1.9.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (3.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: setuptools in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (65.5.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\us\anaconda3\lib\site-packages (from mlxtend) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\us\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\us\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\us\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\us\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.21.0

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
cols = ['LSTAT', 'INDUS', 'NOX', 'RM', 'MEDV']
scatterplotmatrix(df[cols].values, figsize=(10, 8), names=cols, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df[cols].values
# Out:
# array([[ 4.98 ,  2.31 ,  0.538,  6.575, 24.   ],
#        [ 9.14 ,  7.07 ,  0.469,  6.421, 21.6  ],
#        [ 4.03 ,  7.07 ,  0.469,  7.185, 34.7  ],
#        ...,
#        [ 5.64 , 11.93 ,  0.573,  6.976, 23.9  ],
#        [ 6.48 , 11.93 ,  0.573,  6.794, 22.   ],
#        [ 7.88 , 11.93 ,  0.573,  6.03 , 11.9  ]])

# %%
from mlxtend.plotting import heatmap
import numpy as np
cm = np.corrcoef(df[cols].values.T)
hm = heatmap(cm, row_names=cols, column_names=cols)
plt.show()
